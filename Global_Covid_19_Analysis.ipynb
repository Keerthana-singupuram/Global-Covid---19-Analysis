# %% [markdown]
# <a href="https://colab.research.google.com/github/Keerthana-singupuram/Global-Covid---19-Analysis/blob/main/Global_Covid_19_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Global Covid - 19 Analysis**
#
# The analysis gives analysis of top countries with highest number of covid cases based on 124 countries.
#
# **Dataset:**
#
# This dataset contains 127 rows , in CSV format:
#
# Based on the below factors, the data is analysed so as to understand top 10 countries with maximum cases registered along with the severity of cases.
#
# The factors include Country, Total Cases, Recovered Cases, Active Cases, Critical Cases, Year etc.
#
# Based on the above factors and recorded data, here is the analysis of Global Covid - 19 Cases.
#
# It is observed that Maldives has maximum cases and there 5 countries with 'Extreme' level of active cases.
#
# ![MS Excel Project 3 -Maven Upload.jpg](data:image/jpeg;base64,...)
